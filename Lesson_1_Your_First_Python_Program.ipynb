# %% [markdown]
# <a href="https://colab.research.google.com/github/fzhang00/fzhang00.github.io/blob/master/Lesson_1_Your_First_Python_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to your first Python lesson. In this lesson, we will build your first Python program together.
#
# * Take away
#   * Installation
#   * What is a Python file
#   * What can I use to create Python program
#   * How to run a Python program
#   * Our first program with ```print()``` and ```input()```
#
# Let's begin...
#
# # 1. Installation
#
# There are many flavor of Python installation.
#
# * **No installation**. We can run Python code right here on Google colab notebook. There is no installation required. However, you are limited to the packages supported by the web service
# * **Plain Python**. You can install Python from [python.org](https://python.org) This is plain Python, which means it doesn't has any commonly used third party packages. You can install those packages afterwards with pip.
# * **Python Distribution (Recommended)**. Many organization offers Python distribution, which bundles Python and many common third party packages. From feature rich Anaconda Python, to entry level Mu. These distribution are powerful right out of the box, and should cover most of your learning need.
#
# ## 1.1 Install Mu Editor
#
# I recommend a combination of Google Colab and Mu editor for this series of lesson.
#
# You can download Mu editor from [here](https://codewith.mu/en/download)
#
# Get started with Mu following this tutorial: [tutorial](https://codewith.mu/en/tutorials/1.1/start)

# %% [markdown]
# # 2. What is a Python File
#
# Your program needs to be written in a text file that ends with file extension ```.py```. Python program recgonizes the .py file as a Python program.
#
# We can create .py file in any text editor. The Mu editor saves your code to .py file by default.
#
# ![save_py.png](data:image/png;base64,...)

# %% [markdown]
# # 3. How to Create and Run Python Program
#
# When you write some Python code, and save the file as a .py file. You've created a Python program. Let's make a one line Python program.
#
# ## 3.1 Run Python Code in Notebook
#
# We can run Python code directly in Jupyter Notebook.
#
# Click the cell below and press Shift+Enter. You should see "Hello World" printed out below the code cell.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## 3.2 Run Python Code in IDE (Mu Editor)
#
# In your Mu editor, remove the first line and start typing the code from the cell above at the beginning of the line.
#
# Press ```Save``` button and give your program a name.
#
# * name should not contains special character except for the under score ```_```
#
# The Press ```Run```
#
# You've just created your first Python program. Simple! Right?
#
# What we just did here is creating and running a Python program from an IDE. IDE stands for integrated development environment. Most developer run their Python program this way when they are developing the their program. This is how we will run our program in this series of lesson.
#
# [add_video](https://)

# %% [markdown]
# ## 3.3 How does Python Read Your Program
#
# Python read your program line by line starting from the first line of your .py file.
#
# **Python is a interpreting language.** It reads a line, and performs the tasks right away. It doesn't require compiling, like Java, C, C++.
#
# This make it very easy to interact with Python code. We can get Python to run just one line of code by typing the code in console and see what comes out. We can also complete the whole program in a .py file and ask Python to run the whole file.

# %% [markdown]
# # 4 Better First Program
#
# Let's build a better first program. How about letting your Python program greets its user? We'll use function ```print()``` and ```input()``` to do that.
#
# ## 4.1 print()
#
# print() is probably the most often used function in Python. We use it to display text on screen. Let's see a few way to print.

# %%
# 1. print string directly
print("Hello, my name is Python")
# Out:
# Hello, my name is Python

# %% [markdown]
# * We can print string directly. **String is defined by some text enclosed by a pair of quotes.**
# * The # key in Python code means all text following the # key on that line is **comment**. Comment are for coder to read, for documenting the code, or for temperorily disable part of the code during debugging.

# %%
# 2. print variable value
a_variable = "I was created by Guido van Rossum, and was released to the public in 1991."
print(a_variable)
# Out:
# I was created by Guido van Rossum, and was released to the public in 1991.

# %% [markdown]
# * We defined a variable named ```a_variable```, and assigned it with some string as its value "I was created by......"
# * We print out the value of the variable by directly putting the variable name ```a_variable``` into the bracket of print() function.

# %%
# 3. print multiple items
age = 2021-1991
print("I am", age, "years old")
# Out:
# I am 30 years old

# %% [markdown]
# * We defined another variable named ```age``` and performed a subtraction to calculate the age of Python. The result of this subtraction is saved as the value of this variable.
# * We can insert multiple items into print() function, separating them by coma ```,```. In this example, we print string and variable

# %%
# 4. using f operator
age = 2021-1991
print(f"I am {age} years old")
# Out:
# I am 30 years old

# %% [markdown]
# * Another way to combine variable into string is to use f operator. We type ```f``` before the string, then enclose the variable name with curly bracket ```{}```

# %% [markdown]
# ## 4.2 Input()
#
# The ```input``` function allows user to input information to our program. Let's use this function to get user's name.

# %%
user_name = input("What is your name?")
# Out:
# What is your name?Helen

# %% [markdown]
# * Python call input() function which prints out a question on the screen, then waits for user to type in their name.
# * When user types his name in and press ```Enter```, the information gets stored into a variable named ```user_name```
#
# Now let's use the ```user_name``` to make a sentence.

# %%
print(f"Hi, {user_name}. Nice to meet you!")
# Out:
# Hi, Helen. Nice to meet you!

# %% [markdown]
# There it is. A Python program that greets its user.
#
# You can copy and paste the code into your Mu editor and run it all together instead of cell by cell.
